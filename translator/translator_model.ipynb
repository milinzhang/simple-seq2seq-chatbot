# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import time
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Embedding, Dense, GRU

# %% [markdown]
# # Data Preprocessing

# %%
data_path = 'cmn.txt'

# %%
NUM_SAMPLES = 10000

# %%
df = pd.read_table(data_path,header=None).iloc[:NUM_SAMPLES,:,]
df.columns=['english','chinese']
df['english'] = df['english'].apply(lambda x: '\t'+x+'\n') # add \t and \n as bos and eos symbol

English_texts = df.english.values.tolist()
Chinese_texts = df.chinese.values.tolist()

English_corpus = sorted(list(set(df.english.unique().sum())))
Chinese_corpus = sorted(list(set(df.chinese.unique().sum())))

# %%
IN_LEN = max([len(i) for i in Chinese_texts])
OUT_LEN = max([len(i) for i in English_texts])
INPUT_DICTSIZE = len(Chinese_corpus)
OUTPUT_DICTSIZE = len(English_corpus)

# %%
N_unit = 256
BatchSize = 64
EmbedSize = 128

# %%
encoder_input = np.zeros((NUM_SAMPLES,IN_LEN,INPUT_DICTSIZE),dtype='float32')
decoder_input = np.zeros((NUM_SAMPLES,OUT_LEN,OUTPUT_DICTSIZE),dtype='float32')
decoder_output = np.zeros((NUM_SAMPLES,OUT_LEN,OUTPUT_DICTSIZE),dtype='float32')

# %%
input_dict = {char:index for index,char in enumerate(Chinese_corpus)}
input_dict_reverse = {index:char for index,char in enumerate(Chinese_corpus)}
target_dict = {char:index for index,char in enumerate(English_corpus)}
target_dict_reverse = {index:char for index,char in enumerate(English_corpus)}

# %%
for seq_index,seq in enumerate(Chinese_texts):
    for char_index, char in enumerate(seq):
        encoder_input[seq_index,char_index,input_dict[char]] = 1

# %%
for seq_index,seq in enumerate(English_texts):
    for char_index,char in enumerate(seq):
        decoder_input[seq_index,char_index,target_dict[char]] = 1
        if char_index > 0:
            decoder_output[seq_index,char_index-1,target_dict[char]] = 1

# %% [markdown]
# # Training Model

# %%
# define encoder

def create_encoder(inputdim, inputlen, n_units):
    
    encoder_input = Input((inputlen,inputdim,))
    encoder = GRU(n_units, return_state = True)
    _, encoder_state = encoder(encoder_input)
    
    encoder=Model(encoder_input, encoder_state)
    
    return encoder

# %%
# define decoder. notice that this model is only used in training

def create_decoder(inputdim,inputlen, n_units):
    # input of answers
    decoder_input = Input((inputlen,inputdim,))
    # input of encoder state vectors
    initial_state = Input((n_units,))
    decoder = GRU(n_units, return_sequences = True, return_state = True)
    # the state we dont need in training model
    decoder_output,_ = decoder(decoder_input,initial_state = initial_state)
    decoder_dense = Dense(inputdim, activation = 'softmax')
    decoder_output_ = decoder_dense(decoder_output)
    
    decoder=Model([decoder_input,initial_state],decoder_output_)
    
    return decoder

# %%
encoder=create_encoder(INPUT_DICTSIZE,IN_LEN,N_unit)

# %%
encoder.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 20, 2621)]        0
# _________________________________________________________________
# gru_2 (GRU)                  [(None, 256), (None, 256) 2211072
# =================================================================
# Total params: 2,211,072
# Trainable params: 2,211,072
# Non-trainable params: 0
# _________________________________________________________________

# %%
decoder=create_decoder(OUTPUT_DICTSIZE,OUT_LEN,N_unit)

# %%
decoder.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 32, 75)]     0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 256)]        0
# __________________________________________________________________________________________________
# gru_3 (GRU)                     [(None, 32, 256), (N 255744      input_5[0][0]
#                                                                  input_6[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 32, 75)       19275       gru_3[0][0]
# ==================================================================================================
# Total params: 275,019
# Trainable params: 275,019
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# define the optimizer and loss function
optimizer = tf.keras.optimizers.Adam(1e-3)
def loss_function(real, pred): 
    loss = tf.keras.losses.categorical_crossentropy(real,pred)
    return loss

# %%
# define the training step

@tf.function
def train_step(enc_inp,dec_inp,dec_out):
    loss=0

    with tf.GradientTape() as tape:
        encoder_state=encoder(enc_inp)
        initial_state=encoder_state
        prediction=decoder([dec_inp,initial_state])
        loss=loss_function(dec_out,prediction)

    variables = encoder.trainable_variables + decoder.trainable_variables
    gradients = tape.gradient(loss, variables)
    optimizer.apply_gradients(zip(gradients, variables))
    
    return tf.reduce_mean(loss)

# %%
# define the validation loss

def validation_loss(enc_inp,dec_inp,dec_out):
    loss=0
    encoder_state=encoder(enc_inp)
    initial_state=encoder_state
    prediction=decoder([dec_inp,initial_state])
    loss=loss_function(dec_out,prediction)
    
    return loss

# %%
# create tensorflow dataset pipeline for faster processing
# training set
dataset_train = tf.data.Dataset.from_tensor_slices((encoder_input,decoder_input,decoder_output)).shuffle(NUM_SAMPLES)
dataset_train = dataset_train.batch(BatchSize, drop_remainder=True)

# %%
# train the model

Epochs = 100
trainstep_epoch = NUM_SAMPLES//BatchSize
overalltime=0

for epoch in range(Epochs):
    start=time.time()
    total_loss=0
    valid_loss=0
    
    for (batch, (inputq,inputa,targa)) in enumerate(dataset_train.take(trainstep_epoch)):
        batch_loss = train_step(inputq,inputa,targa)
        total_loss += batch_loss
    #print(total_loss)
    print('Epoch {} Loss {:.3f}'.format(epoch+1,total_loss/trainstep_epoch))
    
    stop=time.time()
    timetaken=stop-start
    print('Time taken for 1 epoch {} sec\n'.format(timetaken))
    
    overalltime+=timetaken
    
print('Overall time taken {} min\n'.format(overalltime/60))
# Out:
# Epoch 1 Loss 2.110
# Time taken for 1 epoch 9.173510074615479 sec
#
# Epoch 2 Loss 1.618
# Time taken for 1 epoch 7.700208425521851 sec
#
# Epoch 3 Loss 1.500
# Time taken for 1 epoch 7.196533918380737 sec
#
# Epoch 4 Loss 1.423
# Time taken for 1 epoch 7.318495750427246 sec
#
# Epoch 5 Loss 1.348
# Time taken for 1 epoch 6.894978046417236 sec
#
# Epoch 6 Loss 1.275
# Time taken for 1 epoch 7.033463001251221 sec
#
# Epoch 7 Loss 1.213
# Time taken for 1 epoch 7.469824552536011 sec
#
# Epoch 8 Loss 1.155
# Time taken for 1 epoch 7.172989845275879 sec
#
# Epoch 9 Loss 1.103
# Time taken for 1 epoch 7.340726137161255 sec
#
# Epoch 10 Loss 1.054
# Time taken for 1 epoch 7.375998258590698 sec
#
# Epoch 11 Loss 1.007
# Time taken for 1 epoch 7.183519601821899 sec
#
# Epoch 12 Loss 0.966
# Time taken for 1 epoch 7.123806476593018 sec
#
# Epoch 13 Loss 0.928
# Time taken for 1 epoch 7.119802236557007 sec
#
# Epoch 14 Loss 0.894
# Time taken for 1 epoch 7.241326332092285 sec
#
# Epoch 15 Loss 0.863
# Time taken for 1 epoch 7.037534236907959 sec
#
# Epoch 16 Loss 0.833
# Time taken for 1 epoch 7.283636808395386 sec
#
# Epoch 17 Loss 0.804
# Time taken for 1 epoch 7.1847124099731445 sec
#
# Epoch 18 Loss 0.777
# Time taken for 1 epoch 7.490187644958496 sec
#
# Epoch 19 Loss 0.752
# Time taken for 1 epoch 7.01278281211853 sec
#
# Epoch 20 Loss 0.728
# Time taken for 1 epoch 7.72641134262085 sec
#
# Epoch 21 Loss 0.704
# Time taken for 1 epoch 7.339641571044922 sec
#
# Epoch 22 Loss 0.682
# Time taken for 1 epoch 7.747603893280029 sec
#
# Epoch 23 Loss 0.660
# Time taken for 1 epoch 7.3033998012542725 sec
#
# Epoch 24 Loss 0.640
# Time taken for 1 epoch 6.979217529296875 sec
#
# Epoch 25 Loss 0.620
# Time taken for 1 epoch 7.722651720046997 sec
#
# Epoch 26 Loss 0.599
# Time taken for 1 epoch 7.077836036682129 sec
#
# Epoch 27 Loss 0.580
# Time taken for 1 epoch 7.33503270149231 sec
#
# Epoch 28 Loss 0.561
# Time taken for 1 epoch 7.334489822387695 sec
#
# Epoch 29 Loss 0.541
# Time taken for 1 epoch 6.9790425300598145 sec
#
# Epoch 30 Loss 0.523
# Time taken for 1 epoch 7.419260501861572 sec
#
# Epoch 31 Loss 0.507
# Time taken for 1 epoch 7.473850250244141 sec
#
# Epoch 32 Loss 0.489
# Time taken for 1 epoch 7.107508897781372 sec
#
# Epoch 33 Loss 0.472
# Time taken for 1 epoch 7.395645618438721 sec
#
# Epoch 34 Loss 0.456
# Time taken for 1 epoch 7.003188610076904 sec
#
# Epoch 35 Loss 0.440
# Time taken for 1 epoch 7.3514087200164795 sec
#
# Epoch 36 Loss 0.426
# Time taken for 1 epoch 7.457691431045532 sec
#
# Epoch 37 Loss 0.411
# Time taken for 1 epoch 7.280958414077759 sec
#
# Epoch 38 Loss 0.397
# Time taken for 1 epoch 7.190321207046509 sec
#
# Epoch 39 Loss 0.381
# Time taken for 1 epoch 7.284358978271484 sec
#
# Epoch 40 Loss 0.368
# Time taken for 1 epoch 7.659879684448242 sec
#
# Epoch 41 Loss 0.358
# Time taken for 1 epoch 7.385915756225586 sec
#
# Epoch 42 Loss 0.344
# Time taken for 1 epoch 7.417091608047485 sec
#
# Epoch 43 Loss 0.332
# Time taken for 1 epoch 7.771831512451172 sec
#
# Epoch 44 Loss 0.322
# Time taken for 1 epoch 7.689465284347534 sec
#
# Epoch 45 Loss 0.311
# Time taken for 1 epoch 7.219224214553833 sec
#
# Epoch 46 Loss 0.300
# Time taken for 1 epoch 7.241839408874512 sec
#
# Epoch 47 Loss 0.289
# Time taken for 1 epoch 6.973336696624756 sec
#
# Epoch 48 Loss 0.281
# Time taken for 1 epoch 7.410496711730957 sec
#
# Epoch 49 Loss 0.272
# Time taken for 1 epoch 6.965384006500244 sec
#
# Epoch 50 Loss 0.263
# Time taken for 1 epoch 7.146034479141235 sec
#
# Epoch 51 Loss 0.255
# Time taken for 1 epoch 7.085161924362183 sec
#
# Epoch 52 Loss 0.246
# Time taken for 1 epoch 7.169923305511475 sec
#
# Epoch 53 Loss 0.239
# Time taken for 1 epoch 7.752758979797363 sec
#
# Epoch 54 Loss 0.230
# Time taken for 1 epoch 7.427171945571899 sec
#
# Epoch 55 Loss 0.224
# Time taken for 1 epoch 7.043355703353882 sec
#
# Epoch 56 Loss 0.216
# Time taken for 1 epoch 7.7208027839660645 sec
#
# Epoch 57 Loss 0.208
# Time taken for 1 epoch 7.268869400024414 sec
#
# Epoch 58 Loss 0.201
# Time taken for 1 epoch 7.136752128601074 sec
#
# Epoch 59 Loss 0.197
# Time taken for 1 epoch 7.505473375320435 sec
#
# Epoch 60 Loss 0.193
# Time taken for 1 epoch 7.042762517929077 sec
#
# Epoch 61 Loss 0.186
# Time taken for 1 epoch 7.043076038360596 sec
#
# Epoch 62 Loss 0.180
# Time taken for 1 epoch 7.048693656921387 sec
#
# Epoch 63 Loss 0.176
# Time taken for 1 epoch 7.657822370529175 sec
#
# Epoch 64 Loss 0.173
# Time taken for 1 epoch 7.03829026222229 sec
#
# Epoch 65 Loss 0.167
# Time taken for 1 epoch 7.088164329528809 sec
#
# Epoch 66 Loss 0.161
# Time taken for 1 epoch 7.137615919113159 sec
#
# Epoch 67 Loss 0.156
# Time taken for 1 epoch 7.086111068725586 sec
#
# Epoch 68 Loss 0.152
# Time taken for 1 epoch 6.91912579536438 sec
#
# Epoch 69 Loss 0.146
# Time taken for 1 epoch 7.026556491851807 sec
#
# Epoch 70 Loss 0.143
# Time taken for 1 epoch 7.1290953159332275 sec
#
# Epoch 71 Loss 0.141
# Time taken for 1 epoch 7.340522289276123 sec
#
# Epoch 72 Loss 0.135
# Time taken for 1 epoch 7.065913200378418 sec
#
# Epoch 73 Loss 0.134
# Time taken for 1 epoch 6.95304012298584 sec
#
# Epoch 74 Loss 0.134
# Time taken for 1 epoch 7.2397356033325195 sec
#
# Epoch 75 Loss 0.131
# Time taken for 1 epoch 7.368941783905029 sec
#
# Epoch 76 Loss 0.124
# Time taken for 1 epoch 7.2720441818237305 sec
#
# Epoch 77 Loss 0.121
# Time taken for 1 epoch 7.146416425704956 sec
#
# Epoch 78 Loss 0.120
# Time taken for 1 epoch 7.262796878814697 sec
#
# Epoch 79 Loss 0.117
# Time taken for 1 epoch 7.53709602355957 sec
#
# Epoch 80 Loss 0.111
# Time taken for 1 epoch 7.6650309562683105 sec
#
# Epoch 81 Loss 0.112
# Time taken for 1 epoch 7.2250659465789795 sec
#
# Epoch 82 Loss 0.112
# Time taken for 1 epoch 7.056737661361694 sec
#
# Epoch 83 Loss 0.112
# Time taken for 1 epoch 6.944514274597168 sec
#
# Epoch 84 Loss 0.108
# Time taken for 1 epoch 7.045506954193115 sec
#
# Epoch 85 Loss 0.102
# Time taken for 1 epoch 6.859174728393555 sec
#
# Epoch 86 Loss 0.096
# Time taken for 1 epoch 7.270177364349365 sec
#
# Epoch 87 Loss 0.092
# Time taken for 1 epoch 7.586886882781982 sec
#
# Epoch 88 Loss 0.089
# Time taken for 1 epoch 6.913747310638428 sec
#
# Epoch 89 Loss 0.090
# Time taken for 1 epoch 7.113981246948242 sec
#
# Epoch 90 Loss 0.092
# Time taken for 1 epoch 7.129590034484863 sec
#
# Epoch 91 Loss 0.095
# Time taken for 1 epoch 6.910393714904785 sec
#
# Epoch 92 Loss 0.094
# Time taken for 1 epoch 7.434770345687866 sec
#
# Epoch 93 Loss 0.098
# Time taken for 1 epoch 7.067399024963379 sec
#
# Epoch 94 Loss 0.093
# Time taken for 1 epoch 7.365305662155151 sec
#
# Epoch 95 Loss 0.084
# Time taken for 1 epoch 7.464964389801025 sec
#
# Epoch 96 Loss 0.077
# Time taken for 1 epoch 7.4821484088897705 sec
#
# Epoch 97 Loss 0.074
# Time taken for 1 epoch 6.893122911453247 sec
#
# Epoch 98 Loss 0.072
# Time taken for 1 epoch 7.176896810531616 sec
#
# Epoch 99 Loss 0.077
# Time taken for 1 epoch 7.464603662490845 sec
#
# Epoch 100 Loss 0.081
# Time taken for 1 epoch 7.191999435424805 sec
#
# Overall time taken 12.125336050987244 min

# %%
# save parameters after training
encoder.save_weights('./data/gru_enc_test.h5')
decoder.save_weights('./data/gru_dec_test.h5')
